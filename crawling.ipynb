# %% [markdown]
# 가수 데이터셋을 활용해서 리스트 뽑아내기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 가수정보 데이터셋 확인

# %%
import pandas as pd

# Load the data
file_path = '/content/drive/MyDrive/1104artist.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe
data.head()
# Out:
#    Unnamed: 0    name nation gender group             era  \
# 0           0     뉴진스     KO      f     y            2020
# 1           1     다비치     KO      f     y  2000,2010,2020
# 2           2    블랙핑크     KO      f     y       2010,2020
# 3           3    스테이씨     KO      f     y            2020
# 4           4  프로미스나인     KO      f     y       2010,2020
#
#                   genre
# 0   댄스, R&B/Soul, 국내드라마
# 1        발라드, 국내드라마, 댄스
# 2         댄스, 랩/힙합, POP
# 3  댄스, R&B/Soul, 일렉트로니카
# 4        댄스, 발라드, 국내드라마

# %%
artist_list = data['name'].drop_duplicates().tolist()
artist_list
# Out:
# ['뉴진스',
#  '다비치',
#  '블랙핑크',
#  '스테이씨',
#  '프로미스나인',
#  '레드벨벳',
#  'NCT127',
#  '방탄소년단',
#  '세븐틴',
#  '데이식스',
#  '몬스타엑스',
#  '루시',
#  '아이유',
#  '이영지',
#  '백예린',
#  '볼빨간사춘기',
#  '태연',
#  '정국',
#  '성시경',
#  '박재범',
#  '쿠기',
#  '임한별',
#  '새소년',
#  'wavetoearth',
#  '잔나비',
#  '검정치마',
#  '쏜애플',
#  '10cm',
#  '우효',
#  '최유리',
#  '치즈',
#  '크러쉬',
#  '기리보이',
#  '아리아나그란데',
#  '테일러스위프트',
#  '켈리클락슨',
#  '도자캣',
#  '휘트니휴스턴',
#  '켈라니',
#  '에드시런',
#  '맥밀러',
#  '콜드플레이',
#  '마이클잭슨',
#  '찰리푸스',
#  '더위캔드',
#  '지바노프',
#  '제이미',
#  'ELO',
#  '키디비',
#  '김범수',
#  '릴러말즈',
#  '주영',
#  '이하이',
#  'GSoul',
#  'Rad Museum',
#  '이바다',
#  '홍다빈',
#  '빈센트블루',
#  'DeVita',
#  '딘',
#  '레오',
#  '박봄',
#  '헤이즈',
#  '콜드',
#  '미소',
#  'Chancellor',
#  '정엽',
#  '거미',
#  'SOMA',
#  '정기고',
#  '휘성',
#  '베이빌론',
#  '보니',
#  'Gist',
#  '구원찬',
#  'Ra.D',
#  '밤비로얄프린스',
#  '브라운아이드소울',
#  '범키',
#  'Otis lim',
#  '비비',
#  '대니딕',
#  '빅나티',
#  'DUT2',
#  '서사무엘',
#  '문수진',
#  '원슈타인',
#  '다운',
#  '자이언티',
#  '수비',
#  'SURAN',
#  '나얼',
#  '시도',
#  '키엘',
#  '유라',
#  '루디',
#  'SOLE',
#  '브라운아이즈',
#  '브라운 아이즈',
#  '로이킴',
#  '케이시',
#  'MC the max',
#  '이무진',
#  '데이먼스이어',
#  '산들',
#  '우디',
#  '서인국',
#  'SG워너비',
#  '장덕철',
#  '임영웅',
#  '경서',
#  '김필',
#  '디셈버',
#  '김민석',
#  '바이브',
#  '정동하',
#  '멜로망스',
#  '비투비',
#  '정은지',
#  '악뮤',
#  '임창정',
#  '닐',
#  '빛과 소금',
#  '포지션',
#  '손디아',
#  '심수봉',
#  '이승훈',
#  '한동근',
#  '너드커넥션',
#  '부활',
#  '조성모',
#  '노을',
#  '린',
#  '전건호',
#  '테이',
#  '경서예지',
#  '규현',
#  '박효신',
#  '이소라',
#  '조정석',
#  '버나드박',
#  '정승환',
#  '전람회',
#  '카더가든',
#  '김연지',
#  '이문세',
#  '어반자카파',
#  '김광진',
#  '마크툽',
#  '제이세라',
#  '이수영',
#  '조용필',
#  '박정현',
#  '박재정',
#  '015B',
#  '더클래식',
#  '허각',
#  '산울림',
#  '변진섭',
#  '신승훈',
#  '지아',
#  'HYNN',
#  '김민우',
#  '혁오',
#  '윤종신',
#  '유재하',
#  '백지영',
#  'NCT DREAM',
#  '씨엔블루',
#  '에이핑크',
#  '애프터스쿨',
#  '카라',
#  'NCT',
#  '프리스틴',
#  'RIIZE',
#  'iKON',
#  '오마이걸',
#  'f(x)',
#  '투모로우바이투게더',
#  '러블리즈',
#  '인피니트',
#  '아이들',
#  '우주소녀',
#  '보아',
#  '원어스',
#  '에이티즈',
#  'Aespa',
#  'TREASURE',
#  '원위',
#  '블락비',
#  '샤이니',
#  'GOT7',
#  '동방신기',
#  '미쓰에이',
#  '엑소',
#  '소녀시대',
#  'DAY6',
#  '빅뱅',
#  'ITZY',
#  'Stray kids',
#  'APRIL',
#  '원더걸스',
#  '이달의 소녀',
#  '엔플라잉',
#  '아이브',
#  '레이디스 코드',
#  'AOA',
#  '4minute',
#  'B1A4',
#  'NCT U',
#  '마마무',
#  '15&',
#  '더보이즈',
#  'NewJeans',
#  'GLAM',
#  '2NE1',
#  '비',
#  '아이즈원',
#  'NMIXX',
#  'BLACKPINK',
#  '브라운아이드걸스',
#  '씨스타',
#  '슈퍼주니어',
#  'NCT 127',
#  '2AM',
#  'WINNER',
#  'Xdinary Heroes',
#  'LE SSERAFIM (르세라핌)',
#  'TWICE (트와이스)',
#  '오존',
#  '정아로',
#  '유다빈밴드',
#  '이세계',
#  '10CM',
#  '오월오일',
#  '경제환',
#  '결',
#  '소수빈',
#  '진동욱',
#  '이아람',
#  '그래쓰',
#  '참솜',
#  '선우정아',
#  '위수',
#  '보수동쿨러',
#  'Kumira',
#  'Cram',
#  'HERD',
#  '김마리',
#  '오웬',
#  '찰리빈웍스',
#  '태평양',
#  '윤지영',
#  '프롬',
#  '윤딴딴',
#  '적재',
#  '마리슈',
#  '이주열',
#  '이꿈',
#  '웨스턴카잇',
#  '하현상',
#  '아도이',
#  '사뮈',
#  '신해경',
#  '델리스파이스',
#  '전진희',
#  '신지훈',
#  'Off the menu',
#  '넬',
#  '김뜻돌',
#  '랜드오브피스',
#  '실리카겔',
#  '나상현씨밴드',
#  'TRPP',
#  '검은잎들',
#  '오핑',
#  '세이수미',
#  'O.O.O',
#  '장기하',
#  '자우림',
#  '플라워',
#  '체리필터',
#  '노브레인',
#  '크라잉넛',
#  '브로콜리너마저',
#  '서태지',
#  '국카스텐',
#  '익스',
#  '타카피',
#  '위치스',
#  '미스미스터',
#  '네미시스',
#  '러브홀릭',
#  '리리밴드',
#  '더크로스',
#  '버즈',
#  '긱스',
#  '언니네 이발관',
#  '짙은',
#  '신해철',
#  '윤도현',
#  '9와 숫자들']

# %% [markdown]
# ## 1. crawling

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.15.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
from selenium.webdriver.common.by import By

# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests
from itertools import repeat

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time


# options.add_argument('headless')  # 배경 실행
df_music = pd.DataFrame()

def search_artist_songs(artist_name):
    global df_music
    # 크롬드라이버 열기
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=options)
    driver.maximize_window()  # 크롬창 크기 최대

        # 드라이버가 해당 url 접속
    url = 'https://www.melon.com/index.htm'  # 멜론 메인 페이지
    driver.get(url)
    time.sleep(2)

    # 검색창 클릭
    element = driver.find_element(By.XPATH, '//*[@id="top_search"]')
    element.click()
    element.send_keys(artist_name)
    search_element = driver.find_element(By.XPATH, '//*[@id="gnb"]/fieldset/button[2]/span').click()
    time.sleep(2)

    song_element = driver.find_element(By.XPATH, '//*[@id="conts"]/div[4]/div/div[1]/a/span[1]')
    song_element.click()
    time.sleep(2)

    # html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    # 노래 정보 가져오기
    # 곡 정보 div class
    song_containers = soup.find_all('div', class_='wrap pd_none')
    song_list = []
    # 각 컨테이너에 대해 처리
    for container in song_containers:
        # 먼저 <a> 태그로 시도
        a_tag = container.find('a', class_='fc_gray')
        if a_tag:  # <a> 태그가 존재하면 그 값을 사용
            song_list.append(a_tag.get_text().strip())
        else:  # <a> 태그가 없으면 <span> 태그로 시도
            span_tag = container.find('span', title=True)
            if span_tag:  # <span> 태그가 존재하면 그 값을 사용
                song_list.append(span_tag.get('title').strip())

    # 좋아요 수 가져오기
    like_num_list = [title.get_text() for title in soup.find_all('span', attrs={'class': 'cnt'})]
    # 데이터 정제 후 int 형태로 변환
    like_list = [int(item.replace('\n총건수\n', '').replace(',', '')) for item in like_num_list]
    # 앨범 커버명 가져오기
    album_list = [div.find('a').get_text() for div in soup.find_all('div', class_='ellipsis', style='max-width:90%') if div.find('a')]
    # 아티스트명 가져오기
    artist_list = []

    for div in soup.find_all('div', class_='ellipsis', style='max-width:122px'):
        artists = div.find_all('a', class_='fc_mgray')  # Find all artist <a> tags within the div
        unique_artists = set()  # Create a set to keep track of unique artist names
        for artist in artists:
            artist_name = artist.get_text().strip()
            unique_artists.add(artist_name)
        artist_names = ', '.join(unique_artists)
        artist_list.append(artist_names)

    df = pd.DataFrame({
            "아티스트": artist_list,
            "좋아요": like_list,
            "곡제목": song_list,
            "앨범명": album_list
        })

    df_music = pd.concat([df_music, df], ignore_index=True)
    print(df_music.tail())
    print("last")
    time.sleep(10)

# %%
# 가수 정보 기반으로 곡 정보 데이터셋 df화
for i in range(0, len(artist_list)):
    try:
        search_artist_songs(artist_list[i])
    except Exception as e:
        print(f"An error occurred with {artist_list[i]}: {e}")  # 오류 메시지를 출력하거나 로깅할 수 있습니다.
        continue  # 다음 반복으로 넘어갑니다.

# %%
df_music
# Out:
#                    아티스트     좋아요                                 곡제목  \
# 0             IVE (아이브)   41792                          Either Way
# 1             IVE (아이브)  199173                                I AM
# 2             IVE (아이브)   18221                      Off The Record
# 3             IVE (아이브)   39981                              I WANT
# 4             IVE (아이브)  243486                           LOVE DIVE
# ..                  ...     ...                                 ...
# 768  LE SSERAFIM (르세라핌)    3894          Blue Flame (Japanese ver.)
# 769  LE SSERAFIM (르세라핌)    7263  The World Is My Oyster (2023 Ver.)
# 770  LE SSERAFIM (르세라핌)    3870            FEARLESS (Japanese ver.)
# 771  LE SSERAFIM (르세라핌)    1501                    Guardian (Inst.)
# 772  LE SSERAFIM (르세라핌)    5029            FEARLESS (Japanese ver.)
#
#                           앨범명
# 0                   I'VE MINE
# 1                    I've IVE
# 2                   I'VE MINE
# 3                      I WANT
# 4                   LOVE DIVE
# ..                        ...
# 768                  FEARLESS
# 769                UNFORGIVEN
# 770                  FEARLESS
# 771       BASTIONS OST Part.4
# 772  FEARLESS (Japanese ver.)
#
# [773 rows x 4 columns]

# %%
df_kpop = df_kpop[df_kpop['좋아요'] >= 500]

# %%
df_music['아티스트'].unique()
# Out:
# array(['IVE (아이브)', 'NewJeans', 'TWICE (트와이스)', 'aespa',
#        'Red Velvet (레드벨벳)', '에스파(Asfa)', '마마무 (Mamamoo)', '솔라 (마마무)',
#        '이적', '마마무+', '문별 (마마무)', '케이윌', '루나 (LUNA)', '챈슬러', '예성 (YESUNG)',
#        'FIFTY FIFTY', 'Floating Animal', 'Floating Blue',
#        'Nifty Tom Fifty', 'Leo Fifty Five', 'Fifty Fantastics',
#        'Fifty Grand', 'Fifty Gram', 'Mohamed Bakar', 'Raimytree',
#        'Blue Cat Guy', 'LouisON', 'flywtwo', 'Jazzy Kyle', '프로미스나인',
#        '박지원 (프로미스나인)', '송하영 (프로미스나인)', '정동원', 'ITZY (있지)', '리아 (ITZY)',
#        'Bebe Rexha', '둘째이모 김다비', '레드벨벳-아이린&슬기', '미쓰에이', '카라', '허영지 (카라)',
#        '백현 (BAEKHYUN)', 'B1A4', '구하라 (카라)', '티파니 (TIFFANY)', '박규리 (카라)',
#        "소녀시대 (GIRLS' GENERATION)", "소녀시대-태티서 (Girls' Generation-TTS)",
#        '소녀시대-Oh!GG', 'Apink (에이핑크)', '4minute', '김남주 (에이핑크)',
#        'Apink 초봄 (에이핑크 초봄)', '윤보미 (에이핑크)', '이지혜', '핑코빛 (지석진, 이광수, 에이핑크)',
#        'ABLE (장현승)', '허각', '오하영 (에이핑크)', '윤상', 'AOA', '도화 (AOA)',
#        'AOA CREAM', '혜정 (AOA)', '윤산하 (ASTRO)', 'BLACKPINK', 'Dua Lipa',
#        'Lady Gaga', 'LE SSERAFIM (르세라핌)'], dtype=object)

# %%
df_kpop
# Out:
#                    아티스트     좋아요                                 곡제목  \
# 0             IVE (아이브)   41792                          Either Way
# 1             IVE (아이브)  199173                                I AM
# 2             IVE (아이브)   18221                      Off The Record
# 3             IVE (아이브)   39981                              I WANT
# 4             IVE (아이브)  243486                           LOVE DIVE
# ..                  ...     ...                                 ...
# 768  LE SSERAFIM (르세라핌)    3894          Blue Flame (Japanese ver.)
# 769  LE SSERAFIM (르세라핌)    7263  The World Is My Oyster (2023 Ver.)
# 770  LE SSERAFIM (르세라핌)    3870            FEARLESS (Japanese ver.)
# 771  LE SSERAFIM (르세라핌)    1501                    Guardian (Inst.)
# 772  LE SSERAFIM (르세라핌)    5029            FEARLESS (Japanese ver.)
#
#                           앨범명
# 0                   I'VE MINE
# 1                    I've IVE
# 2                   I'VE MINE
# 3                      I WANT
# 4                   LOVE DIVE
# ..                        ...
# 768                  FEARLESS
# 769                UNFORGIVEN
# 770                  FEARLESS
# 771       BASTIONS OST Part.4
# 772  FEARLESS (Japanese ver.)
#
# [708 rows x 4 columns]

# %%
df_kpop['아티스트'].unique()
# Out:
# array(['IVE (아이브)', 'NewJeans', 'TWICE (트와이스)', 'aespa',
#        'Red Velvet (레드벨벳)', '마마무 (Mamamoo)', '솔라 (마마무)', '이적', '마마무+',
#        '문별 (마마무)', '케이윌', '루나 (LUNA)', '챈슬러', '예성 (YESUNG)',
#        'FIFTY FIFTY', '프로미스나인', '박지원 (프로미스나인)', '송하영 (프로미스나인)', '정동원',
#        'ITZY (있지)', '리아 (ITZY)', 'Bebe Rexha', '둘째이모 김다비', '레드벨벳-아이린&슬기',
#        '미쓰에이', '카라', '허영지 (카라)', '백현 (BAEKHYUN)', 'B1A4', '구하라 (카라)',
#        '티파니 (TIFFANY)', "소녀시대 (GIRLS' GENERATION)",
#        "소녀시대-태티서 (Girls' Generation-TTS)", '소녀시대-Oh!GG', 'Apink (에이핑크)',
#        '4minute', '김남주 (에이핑크)', 'Apink 초봄 (에이핑크 초봄)', '윤보미 (에이핑크)', '이지혜',
#        '핑코빛 (지석진, 이광수, 에이핑크)', 'ABLE (장현승)', '허각', '오하영 (에이핑크)', 'AOA',
#        '도화 (AOA)', 'AOA CREAM', '혜정 (AOA)', '윤산하 (ASTRO)', 'BLACKPINK',
#        'Dua Lipa', 'Lady Gaga', 'LE SSERAFIM (르세라핌)'], dtype=object)

# %%
df_kpop.to_csv('/content/drive/MyDrive/kpop-1.csv')
